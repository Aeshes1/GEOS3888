# %%
import matplotlib.mlab as ml 
import matplotlib.pyplot as plt

# %%
import cartopy.crs as ccrs

###Set up the figure
fig = plt.figure(figsize=(16,12),dpi=150)

ax = plt.axes(projection=ccrs.PlateCarree())
ax.stock_img()
ax.set_extent([-155, -60, -5, 80])
